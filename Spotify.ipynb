# %% [markdown]
# **Spotify Data Science**
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  
import warnings
warnings.filterwarnings('ignore')
sns.reset_orig()

# %%
## Đọc tập tin vào dataframe
from google.colab import drive
drive.mount("/content/gdrive", force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/My Drive/Data_Sicience/')

# %%
spotify=pd.read_csv('spotify.csv',index_col='Date',parse_dates=True)
spotify.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# **Biểu đồ lượt nghe cho 4 bài hát: 'Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.', 'Unforgettable' qua các tháng trong khoàng thời gian 2017-2018**

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify)
plt.title("Daily Gobal Streams of Popular Songs in 2017-2018")
plt.show()
plt.clf()

# %% [markdown]
# **Biểu đồ so sánh lượt nghe giữa 2 bài hát "Shape of You" và "Despacito" qua các thàng trong năm 2017-2018**

# %%
plt.figure(figsize=(12,6))
plt.title("Daily Gobal Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify['Shape of You'],label='Shape of You')
sns.lineplot(data=spotify['Despacito'],label='Despacito')
plt.legend()
plt.show()
plt.clf()

# %% [markdown]
# **Lập bảng thống kê tổng số lượt nghe của mỗi bài hát qua các năm và vẽ biểu đồ**

# %%
spotify_songs = spotify_songs.sort_values(by='Tổng Số lượt nghe', ascending=False)
spotify_songs
# Out:
#                           Tổng Số lượt nghe
# Despacito                         3.290523e+09
# Shape of You                      2.993989e+09
# Something Just Like This          1.386258e+09
# HUMBLE.                           1.311244e+09
# Unforgettable                     1.289151e+09

# %% [markdown]
# **Chart: Total Global Streams of Popular Songs in 2017-2018**

# %%
plt.figure(figsize=(8,6))
colors = sns.color_palette("RdPu_r", 10)
barplot=sns.barplot(data=spotify_songs, x=spotify_songs.index,y='Tổng Số lượt nghe',palette=colors)
plt.ylabel("")
plt.title('Total Global Streams of Popular Songs in 2017-2018')
barplot.set_xticklabels(barplot.get_xticklabels(), rotation=60)
plt.grid(True)
plt.show()
plt.clf()

# %% [markdown]
# **Lập bảng thống kê tổng số lượt nghe của mỗi bài hát qua mỗi năm**

# %%
spotify_=spotify
spotify_['Year']=pd.DatetimeIndex(spotify.index).year
spotify_.groupby('Year').sum()
# Out:
#       Shape of You     Despacito  Something Just Like This       HUMBLE.  \
# Year
# 2017    2954314942  3.258171e+09              1.366415e+09  1.288360e+09
# 2018      39673841  3.235267e+07              1.984340e+07  2.288376e+07
#
#       Unforgettable
# Year
# 2017   1.265162e+09
# 2018   2.398930e+07
